# %%
import sys
sys.path.append('PycharmProjects/mlia/mliac5')
import logRegres
import numpy as np
from importlib import reload 
reload(logRegres)
dataArr, labelMat = logRegres.loadDataSet('PycharmProjects/mlia/mliac5/testSet.txt')
weights = logRegres.gradAscent(dataArr, labelMat)
logRegres.plotBestFit(weights, 'PycharmProjects/mlia/mliac5/testSet.txt')

# %%
logRegres.plotBestFitA(np.array(dataArr), labelMat, weights)
